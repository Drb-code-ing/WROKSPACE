# %%
# JS 模块化
# 浏览器副产品 2015 es6+
# import OpenAI from openai

from openai import OpenAI
import json

client = OpenAI(
    api_key= "sk-42f330c31bc942af850e618865b6283e",
    base_url="https://api.deepseek.com/v1"
)
# 参数的默认值
# 工具函数
# 默认deepseek-chat 可以选择其他模型
# llm 的 Api
# - completions aigc 生成
# - chat + completions 生成接口 对话形式
def get_completions(prompt, model="deepseek-chat") :
    response = client.chat.completions.create(
        model = model,
        messages = [
            {"role" : "user", "content" : prompt}
        ]
    )
    return response.choices[0].message.content

get_completions("什么是 vibe coding")
# Out:
# '这是一个非常有趣的词。**Vibe Coding（氛围编码）** 是近期在AI编程圈（尤其是使用Cursor、GitHub Copilot等AI辅助工具的用户中）流行的一个概念。\n\n简单来说，它指的是一种**高度依赖AI、直觉和即时反馈，而较少依赖传统编程逻辑和深度理解的编码方式**。\n\n如果把传统编程比作“按照图纸精确施工”，那么Vibe Coding就像是“跟着感觉即兴创作”。\n\n### 核心特点\n\n1.  **由“氛围”主导，而非逻辑：** 开发者不再需要从零开始构思每一行代码的逻辑结构。他们更关注于描述一个“感觉”或“功能”，然后让AI去实现。例如，不是写“for循环遍历数组”，而是说“帮我做一个像苹果官网那样丝滑的卡片切换效果”。\n2.  **高度依赖AI补全：** 开发者可能只写一个函数名或几行注释，AI就会自动生成几十行甚至上百行代码。在这种模式下，Tab键（接受AI建议）的使用频率远高于手动敲键盘。\n3.  **“跑起来就好”的心态：** 开发者对生成的代码不求甚解。只要程序能运行、视觉效果符合预期，就算代码内部有冗余、低效或不规范的写法，也往往不会去深究。目标是快速验证想法。\n4.  **迭代式“提需求”：** 开发过程变成了和AI对话。比如：“把这个按钮变圆”、“改一下颜色”、“这里报错了，帮我修一下”。开发者更像是一个**产品经理或创意总监**，而不是一个严格的工程师。\n\n### 一个典型的Vibe Coding流程\n\n> 1.  打开Cursor（或类似的AI编辑器）。\n> 2.  输入提示：“创建一个登录页面，背景是渐变星空，中间有一个毛玻璃效果的卡片。”\n> 3.  AI瞬间生成HTML、CSS和JS代码。页面出来了。\n> 4.  （开发者扫一眼）：“嗯，还不错，但毛玻璃透明度太高了，调低一点。还有，把‘登录’按钮改成圆角更大、带渐变的。”\n> 5.  AI立刻修改。\n> 6.  （开发者再次检查）：“背景星星不会动啊？加点旋转的动画。”\n> 7.  AI再次修改。\n> 8.  几分钟后，一个中等复杂度的登录页面就完成了。开发者在这个过程中，**只描述了需求，几乎没有亲手写过几行代码**。\n\n### Vibe Coding的类比\n\n-   **传统编程：** 像建造一栋房子。你需要设计蓝图、打地基、砌砖、铺设水电……每一步都需要专业知识和精确操作。\n-   **Vibe Coding：** 像在玩《我的世界》的创造模式。你可以直接放置一整栋预设好的房屋，然后对它进行微调。你不需要知道这栋房子是怎么被建造出来的，只要能快速得到你想要的结果就行。\n\n### 优点与争议\n\n**优点：**\n\n-   **速度快到极致：** 将原型开发、个人项目或小型工具的创建时间从“天”缩短到“分钟”或“小时”。\n-   **降低门槛：** 让不懂编程但有创意的人（设计师、产品经理、艺术家）能将自己的想法实现为可用的产品。\n-   **乐趣和创造力：** 更像是和朋友（AI）一起玩，而不是在枯燥地工作。氛围轻松，鼓励试错。\n\n**争议与局限：**\n\n-   **代码质量堪忧：** 生成一段能跑的代码很容易，但生成一段安全、高效、可维护、无潜在Bug的代码很难。Vibe Coding产出的代码通常被称为“旋涡状意大利面条式代码”。\n-   **缺乏深度理解：** 遇到复杂Bug或需要进行深度性能优化时，如果开发者不理解底层原理，会完全无从下手。AI可能会陷入“修好一个Bug，制造三个新Bug”的循环。\n-   **生产环境不适用：** 目前来看，Vibe Coding更适合于**原型验证、小型工具、个人项目**。对于商业级、需要长期维护和多人协作的大型项目，这种方式风险过高。\n-   **认知“空心化”：** 长期依赖Vibe Coding可能导致开发者逐渐丧失调试复杂问题、架构设计和系统优化的能力。\n\n### 总结\n\n**Vibe Coding是AI时代编程文化的一种新形态。** 它代表了一种从“精确建造”到“灵感实现”的范式转变。它不等于“不会编程”，而是**一种新的编程风格**——一种更强调**对话式开发、快速迭代和创意表达**的风格。\n\n就像摄影从胶片到数码再到手机滤镜，不是要取代专业摄影师，而是让更多人能享受“拍照”的乐趣。Vibe Coding也是如此，它不会取代传统编程，但为“用代码创造”这件事，提供了一种更轻松、更快速的入门方式。'

# %%
# python 多行字符串模版
text = f"""
你应当通过尽可能清晰、具体的指令，来明确你希望模型完成的任务。
这能引导模型产出符合预期的结果，同时降低回复内容偏离主题或出现错误的概率。
不要把编写清晰的提示词和精简提示词混为一谈。
很多时候，篇幅更长的提示词能为模型提供更完整的说明与背景信息，进而让输出内容更加详实、贴合需求。
"""
# 字符串模版
prompt = f"""
将三个反引号之间的文本总结为一句话
```{text}```
"""
get_completions(prompt)
# Out:
# '清晰的指令应具体且避免过度精简，较长提示词可提供更完整的背景信息，从而提升模型输出的准确性和相关性。'
